# %%
# Database + Jupyter Integration
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine, text
import warnings
warnings.filterwarnings('ignore')

# Database connection
RDS_ENDPOINT = "my-dev-database.cqx0ougy8gof.us-east-1.rds.amazonaws.com"
conn_str = f"postgresql://postgres:DataScience123!@{RDS_ENDPOINT}:5432/postgres"
engine = create_engine(conn_str)

print("🗄️ Database + Jupyter Integration Demo")

# Load data from database
df = pd.read_sql("SELECT * FROM sales_data LIMIT 1000", engine)

print(f"✅ Loaded {len(df)} records from database")
print(f"📊 Dataset shape: {df.shape}")
print(f"📅 Date range: {df['order_date'].min()} to {df['order_date'].max()}")

# Display first few rows
df.head()
# Out:
# 🗄️ Database + Jupyter Integration Demo
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\envs\ds-master\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\envs\ds-master\Lib\site-packages\sqlalchemy\engine\base.py:3297, in Engine.raw_connection(self)
#    3276 """Return a "raw" DBAPI connection from the connection pool.
#    3277
#    3278 The returned object is a proxied version of the DBAPI
#    (...)   3295
#    3296 """
# -> 3297 return self.pool.connect()
#
# File ~\anaconda3\envs\ds-master\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
# ...
